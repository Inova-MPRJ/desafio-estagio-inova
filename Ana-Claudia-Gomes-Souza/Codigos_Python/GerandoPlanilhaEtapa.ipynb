# %%
import pandas as pd

# %%
etapa = pd.read_csv("siconv_etapa_crono_fisico.csv", sep=';')

# %%
etapa
# Out:
#          ID_META  ID_ETAPA  NR_ETAPA  \
# 0           1230      1109         1
# 1           1233      1112         1
# 2           1234      1111         1
# 3           1234      1113         2
# 4           1234      1110         3
# 5           1240    120041         1
# 6           1241    120058         1
# 7           1242      1150         1
# 8           1243      1120         1
# 9           1243      1119         2
# 10          1244      1122         1
# 11          1250      1124         1
# 12          1250      1125         2
# 13          1251      1131         1
# 14          1251      1130         2
# 15          1251      1129         3
# 16          1251      1128         4
# 17          1252      1127         1
# 18          1252      1126         2
# 19          1253      1134         1
# 20          1253      1133         2
# 21          1253      1132         3
# 22          1253      1135         4
# 23          1254      1145         1
# ...

# %%
excel = pd.ExcelWriter('Atualizada_siconv_etapa_crono_fisico.xlsx', engine='xlsxwriter')

# %%
etapa.to_excel(excel, sheet_name='Dados Sobre Etapas')

# %%
excel.save()
